# %% [markdown]
# # StyleCheck Experiment Data Analysis
#
# ## Setup

# %%
# %matplotlib inline

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from scipy import stats

#Style
plt.style.use('ggplot')
#print(plt.style.available)

# Make the tables look prettier
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
img_folder = "/Users/Dani/Documents/Courses/MLT/12-Master-Thesis/off-with-their-heads/img/"

# %% [markdown]
# ## Imports

# %%
# Imports
final = pd.read_csv('final.csv', sep=";", decimal=",", index_col="id")
trans = pd.read_csv('translations.csv', sep=";", decimal=",")
trans_text = pd.read_csv('translations_text.csv', sep=";", decimal=",")

# Setup speed data
trans["Speed (words/hour)"] = (trans.words * 3600) / trans.time
trans_text["Perceived speed (words/hour)"] = (trans_text.words * 3600) / trans_text.perceived
trans_text["Real speed (words/hour)"] = (trans_text.words * 3600) / trans_text.real
#trans["Perceived Speed (Words/hour)"] = (trans.words * 3600) / trans.perception

# Create categorial data and order it
setups = ["SCRATCH", "PE", "STYLE"]
texts = ["AI", "CHARLOTTE", "GARFIELD"]
speed_types = ["REAL", "PERCEIVED"]
participants = [421, 423, 424, 425, 427, 428, 429, 430, 432]

def setup_categorial(column, categories):
    return column.str.upper().astype("category", categories=categories, ordered=True)

add_setups = lambda col: setup_categorial(col, setups)
add_texts = lambda col: setup_categorial(col, texts)
add_speeds = lambda col: setup_categorial(col, speed_types)

    
trans.setup = add_setups(trans.setup)
trans.text = add_texts(trans.text)
trans.type = add_speeds(trans.type)
trans.id = trans.id.astype("category", categories=participants, ordered=True)

trans_text.setup = add_setups(trans_text.setup)
trans_text.text = add_texts(trans_text.text)
trans_text.id = trans_text.id.astype("category", categories=participants, ordered=True)

# Easy column names
speed = "Speed (words/hour)"
per_speed = "Perceived speed (words/hour)"
real_speed = "Real speed (words/hour)"

# %%
def sns_style(h=6, w=12):
    sns.set_style("whitegrid")
    sns.set_context("paper", font_scale=1.6)
    plt.figure(figsize=(w, h))

# %%
trans.head()
# Out:
#     id  time    setup       text  type  words  Speed (words/hour)
# 0  432  1051    STYLE         AI  REAL     85          291.151284
# 1  432  1111       PE  CHARLOTTE  REAL     85          275.427543
# 2  432   659  SCRATCH   GARFIELD  REAL     81          442.488619
# 3  430   617    STYLE         AI  REAL     85          495.948136
# 4  430  1073  SCRATCH  CHARLOTTE  REAL     85          285.181733

# %%
final.head(2)
# Out:
#                    time      3text 3setup  \
# id
# 421  5/22/2015 17:41:08  charlotte     pe
# 432  5/23/2015 16:54:50  charlotte     pe
#
#                                                      4     5text   5setup  \
# id
# 421  I didn't know much about the topic and I had t...        ai  scratch
# 432  Contenía títulos de obras artísticas que final...  garfield  scratch
#
#                                                      6     7text   7setup  \
# id
# 421  The sentences were simple and there was no hid...        ai  scratch
# 432    Es un texto general y sin terminología técnica.  garfield  scratch
#
#                                                      8 ...        ai  \
# id                                                     ...
# 421  In the Text 2 the suggestions made me doubt a ... ...   scratch
# 432  Ya conocía el tema que trata el texto (Garfield). ...     style
#
#     charlotte garfield    1  \
# id
# 421        pe    style  Yes
# 432        pe  scratch  Yes
#
#                                                      2 30b 30c 30d- 30e  30f
# id
# 421  Detecting which words I could not understand a...   2   1    1   3    4
# 432             Seguir la guía de estilo de Wikipedia.   4   1    3   5    5
#
# [2 rows x 72 columns]

# %% [markdown]
# ## Difficulty

# %% [markdown]
# ### Easy (Question 3)

# %%
sns_style(w=8)
final.groupby(['3text', '3setup']).size().plot(kind="bar")

# %% [markdown]
# We take the time spent translating from scratch and compare it to the time spent in the PE and STYLE setups. Most participants experience the same effect (either a slowing down or a speeding up) for both the PE and STYLE setups.

# %%
final[['time_scratch_pe', 'time_scratch_style']].plot(kind="bar")# ; plt.axhline(0, color='k')

# %%
sns_style(w=8)
sns.barplot(x="participant_id", y="time_ai", hue="ai", data=final);

# %%
final[["time_scratch", "time_pe", "time_style"]].plot(kind="bar")

# %% [markdown]
# ## Which setup was preferred by the translators? [Questions 14, 15, 22, 23, 32, 33]

# %%
p = final[["14", "15", "22", "23", "32", "33"]]

# Since there are no "Very dissatisfied" answers, append a row with 0s to the dataframe
extra = pd.DataFrame([[0,0,0,0,0,0]], columns=["14", "15", "22", "23", "32", "33"], index=["Very dissatisfied"])
p = p.apply(pd.value_counts).append(extra).fillna(0)

# Give better bar names
p.columns = ["SCRATCH Task", "SCRATCH Quality", "PE Task", "PE Quality", "STYLE Task", "STYLE Quality"]

# Plot
plot = p.plot(kind='bar', ylim=(0,8))
plot.set_ylabel("Participant Counts")
plot.set_xlabel("Degree of satisfaction")

# %%
p = final[["14", "22","32"]]

# Since there are no "Very dissatisfied" answers, append a row with 0s to the dataframe
extra = pd.DataFrame([[0,0,0]], columns=["14", "22", "32"], index=["Very dissatisfied"])
p = p.apply(pd.value_counts).append(extra).fillna(0)

# Give better bar names
p.columns = ["SCRATCH Task", "PE Task", "STYLE Task"]

# Plot
plot = p.plot(kind='bar', ylim=(0,8))
plot.set_ylabel("Participant Counts")
plot.set_xlabel("Degree of satisfaction")

# %%
p = final[["15", "23", "33"]]

# Since there are no "Very dissatisfied" answers, append a row with 0s to the dataframe
extra = pd.DataFrame([[0,0,0]], columns=["15", "23", "33"], index=["Very dissatisfied"])
p = p.apply(pd.value_counts).append(extra).fillna(0)

# Give better bar names
p.columns = ["SCRATCH Quality", "PE Quality", "STYLE Quality"]

# Plot
plot = p.plot(kind='bar', ylim=(0,8))
plot.set_ylabel("Participant Counts")
plot.set_xlabel("Degree of satisfaction")

# %%
p
# Out:
#                        SCRATCH Quality  PE Quality  STYLE Quality
# Neutral                              2           2              3
# Somewhat dissatisfied                2           0              1
# Somewhat satisfied                   5           4              4
# Very satisfied                       0           3              1
# Very dissatisfied                    0           0              0

# %%
# Number of translations per text and setup

t = trans_text.groupby(["text", "setup"]).size()
t.unstack("setup").plot(kind="bar", ylim=(0,5), rot="horizontal")

# %% [markdown]
# ***
#
# ## Did their perceived translation speed vary significantly from their real translation speed? [Questions 11, 17, 25]

# %% [markdown]
# From the graphs below it seems

# %%
st = sns.jointplot(per_speed, real_speed, trans_text, kind="reg")
st.set_axis_labels("Overall perceived speed (words/hour)", "Overall real speed (words/hour)")


st = sns.jointplot(per_speed, real_speed, trans_text[trans_text.setup == "STYLE"], kind="reg")
st.set_axis_labels("Perceived STYLE speed (words/hour)", "Real STYLE speed (words/hour)")

st = sns.jointplot(per_speed, real_speed, trans_text[trans_text.setup == "PE"], kind="reg")
st.set_axis_labels("Perceived PE speed (words/hour)", "Real PE speed (words/hour)")

st = sns.jointplot(per_speed, real_speed, trans_text[trans_text.setup == "SCRATCH"], kind="reg")
st.set_axis_labels("Perceived SCRATCH speed (words/hour)", "Real SCRATCH speed (words/hour)")

# %% [markdown]
# Some participants were good at calculating their own speed, other were not:

# %%
p = trans_text[["id", real_speed, per_speed]]
p["diff"] = abs(p[real_speed] - p[per_speed])
p = p[["id", "diff"]].groupby(["id"])
p_mean = p.mean()
p_err = p.std()

p = p_mean.plot(kind="bar", yerr=p_err, ylim=(0,700))
p.set_title("Real vs. perceived time difference per participant")
# Out:
# /usr/local/lib/python3.4/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %% [markdown]
# ### Overall Speed
#
# Overall, the translators translated fastest in the PE setup. The SCRATCH and STYLE setups performed similarly, albeit slightly slower than PE. This is in-line with previous findings.
#
# Despite these results, individual translator variation must be taken into account. The boxplot in Figure X shows the average of the three translations each translator carried out. While some presented little variation, others showed a notable difference in speed depending on the setup or text they were translating. This follows what XXX found.

# %%
trans.head()
# Out:
#     id  time    setup       text  type  words  Speed (Words/hour)
# 0  432  1051    STYLE         AI  REAL     85          291.151284
# 1  432  1111       PE  CHARLOTTE  REAL     85          275.427543
# 2  432   659  SCRATCH   GARFIELD  REAL     81          442.488619
# 3  430   617    STYLE         AI  REAL     85          495.948136
# 4  430  1073  SCRATCH  CHARLOTTE  REAL     85          285.181733

# %%
sns.set_style("whitegrid")
sns.set_context("paper", font_scale=1.6)
plt.figure(figsize=(6, 6))

ll = sns.barplot(x="type", y=speed, data=trans, ci=95, n_boot=20000)
ll.set_title("Real vs. perceived average speed")
ll.set_xlabel("")
ll.set_ylabel("Speed (words/hour)")
ll.set_ylim(100,600)

plt.savefig("/".join([img_folder, "time/time_0.pdf"], format="pdf")

# %%
sns.set_style("whitegrid")
sns.set_context("paper", font_scale=1.6)
plt.figure(figsize=(8, 6))

ll = sns.boxplot(x="id", y=speed, data=trans[trans.type == "REAL"])#, ci=95, n_boot=20000)
ll.set_title("Average speed per participant")
ll.set_xlabel("Participant")
ll.set_ylabel("Real speed (words/hour)")
ll.set_ylim(100,800)

plt.savefig("/".join([img_folder, "time/time_3.pdf"], format="pdf")

# %%
sns.set_style("whitegrid")
sns.set_context("paper", font_scale=1.6)
plt.figure(figsize=(12, 6))

ll = sns.barplot(x="id", y=speed, hue="setup", data=trans[trans.type == "REAL"])
ll.set_title("Speed per participant")
ll.set_xlabel("Participant")
ll.set_ylabel("Real speed (words/hour)")
ll.set_ylim(100,800)
plt.legend(title="Setup", frameon=True)

plt.savefig("/".join([img_folder, "time/time_2.pdf"], format="pdf")

# %%
sns.pairplot(trans[["type", speed]], hue="type")

# %%
sns.set_style("whitegrid")
sns.set_context("paper", font_scale=1.6)

fig, axs = plt.subplots(1,2)
fig.set_size_inches(14,6)

st = sns.barplot(x="setup", y=speed, hue="type", data=trans, ci=95, n_boot=20000, ax=axs[0])
st.set_title("Speed per setup")
st.set_xlabel("Setup")
st.set_ylabel("Speed (words/hour)")
st.set_ylim(100,800)
axs[0].legend(title="", frameon=True)

st = sns.barplot(x="text", y=speed, data=trans, hue="type", ci=95, n_boot=20000, ax=axs[1])
st.set_title("Speed per text")
st.set_xlabel("Text")
st.set_ylabel("Speed (words/hour)")
st.set_ylim(100,800)
plt.legend(title="", frameon=True, loc=9)

plt.savefig("/".join([img_folder, "time/time_1.pdf"]), format="pdf")

# %%
fig, axs = plt.subplots(1,2)
fig.set_size_inches(14,6)

f = trans[trans.type == "REAL"]
st = sns.barplot(x="setup", y=speed, hue="text", data=f, ci=95, n_boot=20000, ax=axs[0])
st.set_title("Real speed per setup and text")
st.set_xlabel("Setup")
st.set_ylabel("Real Speed (words/hour)")
st.set_ylim(100,1100)
axs[0].legend(title="Text")

f = trans[trans.type == "PERCEIVED"]
tt = sns.barplot(x="setup", y=speed, hue="text", data=f, ci=95, n_boot=20000, ax=axs[1])
tt.set_title("Perceived speed per setup and text")
tt.set_xlabel("Setup")
tt.set_ylabel("Perceived Speed (words/hour)")
tt.set_ylim(100,1100)
plt.legend(title="Text")

# %%
fig, axs = plt.subplots(1,2)
fig.set_size_inches(15,6)

f = trans[trans.type == "REAL"]
st = sns.boxplot(x="setup", y=speed, hue="text", data=f, ax=axs[0])
st.set_ylim(100,1100)
st.set_title("Real speed per setup and text")
st.set_xlabel("Setup")
st.set_ylabel("Real Speed (Words/hour)")
axs[0].legend(title="Text")

f = trans[trans.type == "PERCEIVED"]
st = sns.boxplot(x="setup", y=speed, hue="text", data=f, ax=axs[1])
st.set_ylim(100,1100)
st.set_title("Perceived speed per setup and text")
st.set_xlabel("Setup")
st.set_ylabel("Perceived Speed (Words/hour)")
axs[1].legend(title="Text")

# %%
sns.set_style("whitegrid")
sns.set_context("paper", font_scale=1.6)
plt.figure(figsize=(12, 6))

ll = sns.boxplot(x="id", y=speed, hue="type", data=trans)#, ci=95, n_boot=20000)
ll.set_title("Speed per participant")
ll.set_xlabel("Participant")
ll.set_ylabel("Speed (words/hour)")
ll.set_ylim(100,1100)
plt.legend(title="", frameon=True)

#plt.savefig("/".join([img_folder, "time/time_2.pdf"]), format="pdf")

# %%
# Setup figure
fig, ax = plt.subplots(figsize=(10,8))

# Pretty names
tr = trans.rename(columns={'time_wh': 'Real', 'perception_wh': 'Perceived'})


# Total
total = tr[["Real", "Perceived"]]
total_mean = total.mean()
total_err = total.std()
total_plot = total_mean.plot(kind="bar", yerr=total_err, ax=ax, ylim=(0,800),
                             title="Real vs. perceived speed",
                             rot="horizontal",
                             fontsize=16)
total_plot.set_ylabel("Words/hour")


fig, ax = plt.subplots(figsize=(10,8))
# Setup
s = tr[["setup", "Real", "Perceived"]].groupby(["setup"])
s_mean = s.mean()
s_err = s.std()
s = s_mean.plot(kind="bar", yerr=s_err, ax=ax, ylim=(0,800),
                title="Real vs. perceived speed per setup",
                             rot="horizontal",
                             fontsize=16)
s.set_ylabel("Words/hour")
s.set_xlabel("Setup")
s.legend(prop={'size':15})


fig, ax = plt.subplots(figsize=(10,8))
# Text
t = tr[["text", "Real", "Perceived"]].groupby(["text"])
t_mean = t.mean()
t_err = t.std()
t_plot = t_mean.plot(yerr=t_err, ax=ax, kind='bar', ylim=(0,900),
                    title="Real vs. perceived speed per text",
                             rot="horizontal",
                             fontsize=16)
t_plot.set_ylabel("Words/hour")
t_plot.set_xlabel("Text")
t_plot.legend(prop={'size':15})

fig, ax = plt.subplots(figsize=(10,8))
# Participant
p = tr[["id", "Real", "Perceived"]].groupby(["id"])
p_mean = p.mean()
p_err = p.std()
p = p_mean.plot(kind="bar", yerr=p_err, ax=ax, ylim=(0,1100),
                title="Real vs. perceived speed per participant",
                rot="horizontal",
                fontsize=16)
p.set_ylabel("Words/hour")
p.set_xlabel("Participant")
p.legend(prop={'size':15})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-928940f23579> in <module>()
#       7
#       8 # Total
# ----> 9 total = tr[["Real", "Perceived"]]
#      10 total_mean = total.mean()
#      11 total_err = total.std()
#
# /usr/local/lib/python3.4/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1789         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1790             # either boolean or fancy integer index
# -> 1791             return self._getitem_array(key)
#    1792         elif isinstance(key, DataFrame):
#    1793             return self._getitem_frame(key)
#
# /usr/local/lib/python3.4/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    1833             return self.take(indexer, axis=0, convert=False)
#    1834         else:
# -> 1835             indexer = self.ix._convert_to_indexer(key, axis=1)
#    1836             return self.take(indexer, axis=1, convert=True)
#    1837
#
# /usr/local/lib/python3.4/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1110                 mask = check == -1
#    1111                 if mask.any():
# -> 1112                     raise KeyError('%s not in index' % objarr[mask])
#    1113
#    1114                 return _values_from_object(indexer)
#
# KeyError: "['Real' 'Perceived'] not in index"

# %%
s = trans_text[["setup", real_speed, per_speed]]#.groupby(["setup"]).mean()
s["diff"] = 100 - ((s[per_speed] * 100) / s[real_speed])
s = s.groupby(["setup"]).mean()
s
# Out:
# /usr/local/lib/python3.4/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#          Real speed (words/hour)  Perceived speed (words/hour)       diff
# setup
# SCRATCH               291.365502                    477.666667 -77.148148
# PE                    413.700846                    523.809524 -34.234568
# STYLE                 312.419475                    447.316239 -48.574074

# %%
s = trans_text[["setup", real_speed, per_speed]]#.groupby(["setup"]).mean()
s["diff"] = 100 - ((s[per_speed] * 100) / s[real_speed])
s = s.groupby(["setup"]).mean()
s = s["diff"].plot(kind="bar")
s.set_title("% difference in real vs. perceived time per setup")
# Out:
# /usr/local/lib/python3.4/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
t = trans[["text", "time_wh", "perception_wh"]].groupby(["text"]).mean()
t["diff"] = 100 - ((t.perception_wh * 100) / t.time_wh)
t = t["diff"].plot(kind="bar", ylim=(0,50))
t.set_title("% difference in real vs. perceived time per text")

# %% [markdown]
# Their perception was that they were 20-41% faster than they actually were.

# %%
s = trans[["setup", "text", "time_wh", "perception_wh"]].groupby(["setup", "text"]).mean()
s = s.reset_index()
g = sns.FacetGrid(s, col="setup")
g = g.map(sns.barplot, "text", "perception_wh")

# %%
s = trans[["setup", "text", "time_wh", "perception_wh"]].groupby(["setup", "text"]).mean()
s = s.reset_index()

# %%
# Setup the data for the FacetGrid

one = s[["setup", "text", "time_wh"]]
two = s[["setup", "text", "perception_wh"]]
one["time"] = one.time_wh
one["type"] = "Real"
del one["time_wh"]
two["time"] = two.perception_wh
two["type"] = "Perceived"
del two["perception_wh"]

facet = pd.concat([one, two])

# %%
g = sns.FacetGrid(facet, col="text", row="setup", size=4, margin_titles=True)
g = g.map(sns.barplot, "type", "time")
g.set_axis_labels("Real vs. Perceived Speed", "Words/hour");
g.fig.subplots_adjust(wspace=.05, hspace=.05);

# %%
final.head()
# Out:
#                    time      3text   3setup  \
# id
# 421  5/22/2015 17:41:08  charlotte       pe
# 432  5/23/2015 16:54:50  charlotte       pe
# 428  5/23/2015 18:21:09         ai  scratch
# 423  5/24/2015 17:52:07  charlotte  scratch
# 425   5/25/2015 4:51:35         ai       pe
#
#                                                      4     5text   5setup  \
# id
# 421  I didn't know much about the topic and I had t...        ai  scratch
# 432  Contenía títulos de obras artísticas que final...  garfield  scratch
# 428  Utiliza palabras más técnicas que eran más dif...  garfield       pe
# 423  Porque aparecen numerosas referencias y términ...        ai       pe
# 425  Por cuestiones como la mayúscula en "gobierno"...  garfield  scratch
#
#                                                      6      7text   7setup  \
# id
# 421  The sentences were simple and there was no hid...         ai  scratch
# 432    Es un texto general y sin terminología técnica.   garfield  scratch
# 428  No contenía mucha terminología complicada y co...         ai  scratch
# 423  Porque el texto está compuesto de frases corta...         ai       pe
# 425  Texto sencillo, sin grandes cuestiones ortotip...  charlotte    style
#
#                                                      8 ...        ai  \
# id                                                     ...
# 421  In the Text 2 the suggestions made me doubt a ... ...   scratch
# 432  Ya conocía el tema que trata el texto (Garfield). ...     style
# 428  Porque no tenía una traducción ya hecha que en... ...   scratch
# 423  Porque el texto no presenta dificultades mayor... ...        pe
# 425  Porque he comparado qué hace Wikipedia en los ... ...        pe
#
#     charlotte garfield    1  \
# id
# 421        pe    style  Yes
# 432        pe  scratch  Yes
# 428     style       pe  Yes
# 423   scratch    style   No
# 425     style  scratch  Yes
#
#                                                      2 30b 30c 30d- 30e  30f
# id
# 421  Detecting which words I could not understand a...   2   1    1   3    4
# 432             Seguir la guía de estilo de Wikipedia.   4   1    3   5    5
# 428  Que era importante seguir la guía de estilo de...   2   2    3   2    4
# 423                                                NaN   3   2    2   1    3
# 425  Duda que me surgía, consultaba la guía de esti...   4   1    4   2    5
#
# [5 rows x 72 columns]

# %%
st = sns.countplot(x="3setup", data=final)
st.set_title("Hardest translation")

# %%
st = sns.countplot(x="3text", data=final)
st.set_title("Hardest translation")

# %%
st = sns.countplot(x="5text", data=final)
st.set_title("Easiest translation")

# %%
st = sns.countplot(x="5setup", data=final)
st.set_title("Easiest translation")

# %%
final[["3text", "3setup", "5text", "5setup"]]
# Out:
#          3text   3setup      5text   5setup
# id
# 421  charlotte       pe         ai  scratch
# 432  charlotte       pe   garfield  scratch
# 428         ai  scratch   garfield       pe
# 423  charlotte  scratch         ai       pe
# 425         ai       pe   garfield  scratch
# 430   garfield       pe         ai    style
# 424         ai    style   garfield       pe
# 427         ai  scratch  charlotte       pe
# 429  charlotte  scratch   garfield    style
